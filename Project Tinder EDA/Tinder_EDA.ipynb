# %% [markdown]
# # Tinder

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go

# %%
data = pd.read_csv('Speed+Dating+Data.csv', encoding = 'ISO-8859-1')

# %%
# Basic stats

print("Shape of the set (row & columns) : {}".format(data.shape))
print()

print("Display of dataset: ")
display(data.head())
print()

print("Basics statistics: ")
display(data.describe(include='all'))
print()

print("Percentage of missing values: ")
display(100*data.isnull().sum()/data.shape[0])
# Out:
# Shape of the set (row & columns) : (8378, 195)
#
# Display of dataset:
#    iid   id  gender  idg  condtn  wave  round  position  positin1  order  ...  \
# 0    1  1.0       0    1       1     1     10         7       NaN      4  ...
# 1    1  1.0       0    1       1     1     10         7       NaN      3  ...
# 2    1  1.0       0    1       1     1     10         7       NaN     10  ...
# 3    1  1.0       0    1       1     1     10         7       NaN      5  ...
# 4    1  1.0       0    1       1     1     10         7       NaN      7  ...
#
#    attr3_3  sinc3_3  intel3_3  fun3_3  amb3_3  attr5_3  sinc5_3  intel5_3  \
# 0      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
# 1      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
# 2      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
# 3      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
# ...

# %%
list(data.columns)
# Out:
# ['iid',
#  'id',
#  'gender',
#  'idg',
#  'condtn',
#  'wave',
#  'round',
#  'position',
#  'positin1',
#  'order',
#  'partner',
#  'pid',
#  'match',
#  'int_corr',
#  'samerace',
#  'age_o',
#  'race_o',
#  'pf_o_att',
#  'pf_o_sin',
#  'pf_o_int',
#  'pf_o_fun',
#  'pf_o_amb',
#  'pf_o_sha',
#  'dec_o',
#  'attr_o',
#  'sinc_o',
#  'intel_o',
#  'fun_o',
#  'amb_o',
#  'shar_o',
#  'like_o',
#  'prob_o',
#  'met_o',
#  'age',
#  'field',
#  'field_cd',
#  'undergra',
#  'mn_sat',
#  'tuition',
#  'race',
#  'imprace',
#  'imprelig',
#  'from',
#  'zipcode',
#  'income',
#  'goal',
#  'date',
#  'go_out',
#  'career',
#  'career_c',
#  'sports',
#  'tvsports',
#  'exercise',
#  'dining',
#  'museums',
#  'art',
#  'hiking',
#  'gaming',
#  'clubbing',
#  'reading',
#  'tv',
#  'theater',
#  'movies',
#  'concerts',
#  'music',
#  'shopping',
#  'yoga',
#  'exphappy',
#  'expnum',
#  'attr1_1',
#  'sinc1_1',
#  'intel1_1',
#  'fun1_1',
#  'amb1_1',
#  'shar1_1',
#  'attr4_1',
# ...

# %%
# count of missing values
missing_value = pd.DataFrame(data.isna().sum().values.reshape(1,-1), columns= data.columns)
display(missing_value)
# Out:
#    iid  id  gender  idg  condtn  wave  round  position  positin1  order  ...  \
# 0    0   1       0    0       0     0      0         0      1846      0  ...
#
#    attr3_3  sinc3_3  intel3_3  fun3_3  amb3_3  attr5_3  sinc5_3  intel5_3  \
# 0     4404     4404      4404    4404    4404     6362     6362      6362
#
#    fun5_3  amb5_3
# 0    6362    6362
#
# [1 rows x 195 columns]

# %%
missing_value[['match','dec']]
# Out:
#    match  dec
# 0      0    0

# %%
data.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8378 entries, 0 to 8377
# Data columns (total 195 columns):
#  #    Column    Dtype
# ---   ------    -----
#  0    iid       int64
#  1    id        float64
#  2    gender    int64
#  3    idg       int64
#  4    condtn    int64
#  5    wave      int64
#  6    round     int64
#  7    position  int64
#  8    positin1  float64
#  9    order     int64
#  10   partner   int64
#  11   pid       float64
#  12   match     int64
#  13   int_corr  float64
#  14   samerace  int64
#  15   age_o     float64
#  16   race_o    float64
#  17   pf_o_att  float64
#  18   pf_o_sin  float64
#  19   pf_o_int  float64
#  20   pf_o_fun  float64
#  21   pf_o_amb  float64
#  22   pf_o_sha  float64
#  23   dec_o     int64
#  24   attr_o    float64
#  25   sinc_o    float64
#  26   intel_o   float64
#  27   fun_o     float64
#  28   amb_o     float64
#  29   shar_o    float64
#  30   like_o    float64
#  31   prob_o    float64
#  32   met_o     float64
# ...

# %%
# Unique participants
data['iid'].nunique()
# Out:
# 551

# %% [markdown]
# We have 551 unique participants. We will first clean the data to make our dataset more understandable, and second create a dataset with only the unique participants to see their personnal attribute.

# %%
data['gender'] = data['gender'].apply(lambda x: "Woman" if x == 0 else "Man" if x ==1 else x)
data['race'] = data['race'].apply(lambda x: "Black/African" if x==1 else "White-Caucasian/European" if x==2 
                                    else "Latino/Hispanic" if x==3 else "Asian" if x==4 else "Native American" if x==5 else "Other" if x==6 else x)
data["samerace"] = data["samerace"].apply(lambda x: "No" if x==0 else "Yes" if x==1 else x)
data['race_o'] = data['race_o'].apply(lambda x: "Black/African" if x==1 else "White-Caucasian/European" if x==2 
                                    else "Latino/Hispanic" if x==3 else "Asian" if x==4 else "Native American" if x==5 else "Other" if x==6 else x)
data['field_cd'] = data['field_cd'].apply(lambda x: "Law" if x==1 else "Math" if x==2 else "Social Science/Psychologist" if x==3 
                                    else "Medical Science" if x==4 else "Engineering" if x==5 else "English/Creative/Journalism" if x==6 
                                    else "History/Religion/Philosophy" if x==7 else "Business/Finance" if x==8 else "Education/Academia" if x==9 
                                    else "Biological Sciences/Chemistry/Physics" if x==10 else "Social Work" if x==11 
                                    else "Undergrad/Undecide" if x==12 else "Political Science/International Affairs" if x==13 else "Film" if x==14 
                                    else "Fine Arts/Arts Administration" if x==15 else "Languages" if x==16 else "Architecture" if x==17 
                                    else "Other" if x==18 else x)
data['goal'] = data['goal'].apply(lambda x: "Seemed like a fun night out" if x==1 else "To meet new people" if x==2 else "To get a date" if x==3
                                    else "Looking for a serious relationship" if x==4 else "To say I did it" if x==5 else "Other" if x==6 else x)
data['date'] = data['date'].apply(lambda x: "Several times a week" if x==1 else "Twice a week" if x==2 else "Once a week" if x==3 
                                    else "Twice a month" if x==4 else "Once a month" if x==5 else "Several times a year" if x==6 
                                    else "Almost never" if x==7 else x)
data['go_out'] = data['go_out'].apply(lambda x: "Several times a week" if x==1 else "Twice a week" if x==2 else "Once a week" if x==3 
                                    else "Twice a month" if x==4 else "Once a month" if x==5 else "Several times a year" if x==6 
                                    else "Almost never" if x==7 else x)
data['career_c'] = data['career_c'].apply(lambda x: "Lawyer" if x==1 else "Academic/Research" if x==2 else "Psychologist" if x==3 
                                    else "Doctor/Medicine" if x==4 else "Engineer" if x==5 else "Creative Arts/Entertainment" if x==6 
                                    else "Banking/Consulting/Finance/Marketing/Business/CEO/Entrepreneur/Admin" if x==7 else "Real Estate" if x==8 
                                    else "International/Humanitarian Affairs" if x==9 else "Undecided" if x==10 else "Social Work" if x==11 
                                    else "Speech Pathology" if x==12 else "Politics" if x==13 else "Pro sports/Athletics" if x==14 
                                    else "Other" if x==15 else "Journalism" if x==16 else "Architecture" if x==17 else  x)

# %%
# Keep 1 row per participant to analyse each participant easily
data_unique_id = data.drop_duplicates(subset=['iid'], keep='first').copy()
data_unique_id = data_unique_id.reset_index().drop('index', axis=1)
data_unique_id.head()
# Out:
#    iid   id gender  idg  condtn  wave  round  position  positin1  order  ...  \
# 0    1  1.0  Woman    1       1     1     10         7       NaN      4  ...
# 1    2  2.0  Woman    3       1     1     10         3       NaN     10  ...
# 2    3  3.0  Woman    5       1     1     10         9       NaN      6  ...
# 3    4  4.0  Woman    7       1     1     10         6       NaN      3  ...
# 4    5  5.0  Woman    9       1     1     10         4       NaN      1  ...
#
#    attr3_3  sinc3_3  intel3_3  fun3_3 amb3_3  attr5_3 sinc5_3  intel5_3  \
# 0      5.0      7.0       7.0     7.0    7.0      NaN     NaN       NaN
# 1      7.0      6.0       9.0     9.0    4.0      NaN     NaN       NaN
# 2      NaN      NaN       NaN     NaN    NaN      NaN     NaN       NaN
# 3      6.0      5.0       6.0     8.0    5.0      NaN     NaN       NaN
# 4      4.0      5.0      10.0     6.0   10.0      NaN     NaN       NaN
#
#    fun5_3  amb5_3
# 0     NaN     NaN
# 1     NaN     NaN
# ...

# %% [markdown]
# # EDA

# %% [markdown]
# ### Distribution male female

# %%
print(f"Percentage of match : {data['match'].sum() / data['match'].count() * 100}")
# Out:
# Percentage of match : 16.47171162568632

# %% [markdown]
# 16.5 % of dates are convert in a match

# %%
print(f"Percentage of match when first partner like : {data['match'].sum() / data['dec'].sum() * 100}")
print(f"Percentage of match when second partner like : {data['match'].sum() / data['dec_o'].sum() * 100}")
# Out:
# Percentage of match when first partner like : 39.22683342808414
# Percentage of match when second partner like : 39.26031294452347

# %%
gender_df = data_unique_id['gender'].value_counts()
gender_df
# Out:
# Man      277
# Woman    274
# Name: gender, dtype: int64

# %% [markdown]
# There is almost the same proportion of women and men

# %%
sns.countplot(data=data, hue ="gender", x="dec").set_title("Women and Men saying No and Yes")
# Out:
# Text(0.5, 1.0, 'Women and Men saying No and Yes')

# %% [markdown]
# ### Age repartition

# %%
plt.hist(data_unique_id['age'].values, bins=int(data_unique_id['age'].max()-data_unique_id['age'].min()))
plt.title("Age distribution")
plt.xlabel("Age")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
# Age distribution 
sns.kdeplot(data_unique_id[data_unique_id['gender'] == "Man"].age,
            fill=True, color='blue', label='Man')
sns.kdeplot(data_unique_id[data_unique_id['gender'] == "Woman"].age,
            fill=True, color='red', label="Woman")
plt.title("Age distribution per gender")
plt.xlabel("Age")
plt.legend()

# %% [markdown]
# Biggest part of the population is between 22 and 30 years old.
# Let's see age difference between couples when it matchs.

# %%
age_diff = data[['age', 'age_o']].loc[(data['match'] == 1) & (data['gender'] == 'Man')] # we take only 1 gender because each match is on 2 lines
age_diff['age_diff'] = age_diff['age'] - age_diff['age_o']
age_diff['abs_age_diff'] = age_diff['age_diff'].abs()

print(f"Average age of Men matching : {age_diff['age'].mean()}")
print(f"Average age of Women matching : {age_diff['age_o'].mean()}")
# Out:
# Average age of Men matching : 26.353372434017594
# Average age of Women matching : 25.8

# %%
# age difference when it matchs
print(f"Number of couple with Women older than Men : {age_diff['age_diff'].loc[(age_diff['age_diff'] < 0)].count()}")
print(f"Number of couple with the same age : {age_diff['age_diff'].loc[(age_diff['age_diff'] == 0)].count()}")
print(f"Number of couple with Men older than Women : {age_diff['age_diff'].loc[(age_diff['age_diff'] > 0)].count()}")
# Out:
# Number of couple with Women older than Men : 254
# Number of couple with the same age : 69
# Number of couple with Men older than Women : 349

# %% [markdown]
# More couple with men older than women. But it can be explained by the average age of male participants, older than women.

# %%
print(f"Biggest age difference : {age_diff['abs_age_diff'].max()} years")
# Out:
# Biggest age difference : 17.0 years

# %%
age_diff[['age', 'age_o']].loc[age_diff['abs_age_diff'] == age_diff['abs_age_diff'].max()]
# Out:
#        age  age_o
# 1405  39.0   22.0
# 3335  42.0   25.0
# 3342  42.0   25.0

# %%
age_diff.groupby(age_diff['age_diff']).agg('count')
# Out:
#           age  age_o  abs_age_diff
# age_diff
# -14.0       1      1             1
# -13.0       1      1             1
# -12.0       1      1             1
# -11.0       1      1             1
# -10.0       3      3             3
# -9.0       11     11            11
# -8.0        7      7             7
# -7.0        9      9             9
# -6.0       20     20            20
# -5.0       15     15            15
# -4.0       30     30            30
# -3.0       35     35            35
# -2.0       53     53            53
# -1.0       67     67            67
#  0.0       69     69            69
#  1.0       74     74            74
#  2.0       69     69            69
#  3.0       57     57            57
#  4.0       48     48            48
#  5.0       42     42            42
#  6.0       19     19            19
#  7.0       21     21            21
#  8.0        7      7             7
#  9.0        1      1             1
#  10.0       6      6             6
# ...

# %%
plt.hist(age_diff['age_diff'].values, bins=int(age_diff['age_diff'].max()-age_diff['age_diff'].min()))
plt.title("Age difference when it matchs")
plt.xlabel("Age difference")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# The majority of couples are composed of women 2 years older to 3 years younger than men.

# %% [markdown]
# #### How important is race ?

# %% [markdown]
# Race

# %%
race_df = data_unique_id['race'].value_counts()
race_df
# Out:
# White-Caucasian/European    304
# Asian                       136
# Latino/Hispanic              42
# Other                        37
# Black/African                26
# Name: race, dtype: int64

# %%
# Races of participants
color_palette = {"Man":"blue", "Woman":"red"}
fig = plt.figure(figsize = (10,5))
fig = sns.countplot(y = "race", data = data_unique_id, hue = "gender", palette=color_palette).set(title="Races of the participants per gender")
fig = plt.yticks (rotation = 45, fontsize = 10)

# %% [markdown]
# There is a big part of Caucasian in participants.

# %% [markdown]
# Race importance

# %%
data_unique_id['imprace'].value_counts().sort_index()
# Out:
# 0.0       1
# 1.0     189
# 2.0      60
# 3.0      65
# 4.0      33
# 5.0      43
# 6.0      34
# 7.0      35
# 8.0      42
# 9.0      25
# 10.0     17
# Name: imprace, dtype: int64

# %%
print(f"Mean of race importance : {data_unique_id['imprace'].mean()}")
print(f"Mean of race importance for women: {data_unique_id['imprace'].loc[data_unique_id['gender'] == 'Woman'].mean()}")
print(f"Mean of race importance for men: {data_unique_id['imprace'].loc[data_unique_id['gender'] == 'Man'].mean()}")
# Out:
# Mean of race importance : 3.733455882352941
# Mean of race importance for women: 4.115241635687732
# Mean of race importance for men: 3.36

# %%
ax = data[['gender', 'imprace']].groupby('gender').mean().plot(kind='bar', figsize=(12,5), legend=False,
                                            title='Importance of Race, by Gender', ylim=(2,5))
ax.set_xticklabels(['Female', 'Male'], fontsize=12, rotation='horizontal')
ax.set_xlabel('',fontsize=1)

for i in ax.patches:
    ax.text(i.get_x()+.22, i.get_height()+.05, \
            str(round((i.get_height()), 1)), fontsize=12)

# %% [markdown]
# Women declare to care about race more than men.

# %%
fig = sns.countplot(x = "imprace", data = data_unique_id, hue = 'gender', palette=color_palette).set(title="Importance of the Races per gender")

# %%
data_unique_id[['race', 'imprace']].groupby(['race']).agg(['mean', 'min', 'max', 'count'])
# Out:
#                            imprace
#                               mean  min   max count
# race
# Asian                     3.382353  1.0  10.0   136
# Black/African             3.461538  1.0   9.0    26
# Latino/Hispanic           2.666667  1.0   9.0    42
# Other                     2.891892  1.0   8.0    37
# White-Caucasian/European  4.165017  0.0  10.0   303

# %% [markdown]
# Caucasians give more importance to race than other races.

# %%
# Importance of race for each race
fig = sns.FacetGrid(data_unique_id, col='race')
fig.map(plt.hist, 'imprace', bins=10)
axes = fig.axes.flatten()
axes[0].set_title("Asian")
axes[1].set_title("White")
axes[2].set_title("Other")
axes[3].set_title("Hispanic")
axes[4].set_title("Black")
plt.subplots_adjust(top=0.75)
fig.fig.suptitle('Importance of race for each race', fontsize=15)
# Out:
# Text(0.5, 0.98, 'Importance of race for each race')

# %%
# % of match in function of race importance
print(f"Percentage of match for people who think to be of the same race is quite important : {data['match'].loc[(data['imprace']>5)].sum() / data['match'].loc[(data['imprace']>5)].count() * 100}")
print(f"Percentage of match for people who think to be of the same race is not important : {data['match'].loc[(data['imprace']<=5)].sum() / data['match'].loc[(data['imprace']<=5)].count() * 100}")
# Out:
# Percentage of match for people who think to be of the same race is quite important : 13.813311008790288
# Percentage of match for people who think to be of the same race is not important : 17.512690355329948

# %%
# Importance of being of the same race to match
fig = px.histogram(data, y='samerace', color='match', barmode='group', color_discrete_map=color_palette)
fig.update_layout(title = go.layout.Title(text = "Proportion of match for participants of same or different race", x = 0.5))

fig.show()

# %% [markdown]
# People who don't care about the race have more chance to match with a partner.

# %%
# % of match in function of being of the same race
print(f"Percentage of match for people of the same race : {data['match'].loc[(data['samerace']=='Yes')].sum() / data['match'].loc[(data['samerace']=='Yes')].count() * 100}")
print(f"Percentage of match for people of different race : {data['match'].loc[(data['samerace']=='No')].sum() / data['match'].loc[(data['samerace']=='No')].count() * 100}")
# Out:
# Percentage of match for people of the same race : 17.06875753920386
# Percentage of match for people of different race : 16.08060055314105

# %% [markdown]
# But being of the same race makes not a big difference to convert date in match.

# %%
# Rate of positive feedback on the partner of the same race, by gender
data[['dec','samerace', 'gender']].groupby(['gender','samerace']).mean()*100
# Out:
#                        dec
# gender samerace
# Man    No        47.397476
#        Yes       47.466828
# Woman  No        34.718923
#        Yes       39.324487

# %% [markdown]
# Men doesn't change their decision in function of the race, but for women we can see that they are lesslikely to give positive feedback when meeting a man of a different race.

# %%
# Rate of positive feedback on the partner of the same race, by race
data[['dec','samerace', 'race']].groupby(['race','samerace']).mean()*100
# Out:
#                                          dec
# race                     samerace
# Asian                    No        46.870839
#                          Yes       43.750000
# Black/African            No        49.502488
#                          Yes       77.777778
# Latino/Hispanic          No        39.869281
#                          Yes       48.076923
# Other                    No        50.000000
#                          Yes       45.238095
# White-Caucasian/European No        33.549675
#                          Yes       42.988253

# %% [markdown]
# All races have different comportment. Asians and Others tend to give positive feedback more easily when they meet peopel of other race, but it is not significant. For Latinos and Caucasians, they see a positive effect to meet someone of the same race and say yes 10% more easily. The difference for Blacks is impressive because they say yes at more than 77 % when they meet people of the same race.

# %%
color_palette2 = ['yellow', 'brown', 'orange', 'green', 'blue']

fig, ax= plt.subplots(2,2, figsize=(15, 13))

data[(data['samerace']=='No') & (data.gender=='Woman')][['race', 'dec']].groupby('race').mean().T.plot(kind='bar', ax=ax[0][0], legend=True,
                                                        title='Different races, Females', ylim=(0,1), color=color_palette2)

data[(data['samerace']=='No') & (data.gender=='Man')][['race', 'dec']].groupby('race').mean().T.plot(kind='bar', ax=ax[1][0], legend=True,
                                                        title='Different races, Males', ylim=(0,1), color=color_palette2)

data[(data['samerace']=='Yes') & (data.gender=='Woman')][['race', 'dec']].groupby('race').mean().T.plot(kind='bar', ax=ax[0][1], legend=True,
                                                        title='Same race, Females', ylim=(0,1), color=color_palette2)

data[(data['samerace']=='Yes') & (data.gender=='Man')][['race', 'dec']].groupby('race').mean().T.plot(kind='bar', ax=ax[1][1], legend=True,
                                                        title='Same race, Males', ylim=(0,1), color=color_palette2)

fig.suptitle('Rate of positive feedback, by race', fontsize=18)

for i in ax[0][0].patches:
    ax[0][0].text(i.get_x()+.01, i.get_height()+.02, str(round((i.get_height())*100, 1))+'%', fontsize=12)
    
for i in ax[1][0].patches:
    ax[1][0].text(i.get_x()+.01, i.get_height()+.02, str(round((i.get_height())*100, 1))+'%', fontsize=12)
    
for i in ax[0][1].patches:
    ax[0][1].text(i.get_x()+.01, i.get_height()+.02, str(round((i.get_height())*100, 1))+'%', fontsize=12)
    
for i in ax[1][1].patches:
    ax[1][1].text(i.get_x()+.01, i.get_height()+.02, str(round((i.get_height())*100, 1))+'%', fontsize=12)

# %% [markdown]
# Our first impression seems to be confirmed. The race makes not a big difference in men choices, except for Black people who say yes 10% easily when partner is from the same race. For men of the other race, the tendence is the same that what we said before, but difference is not significative.
# But for women, except for Asians and Others, being of the same race is important for Hispanics, Caucasians and Blacks. It is obvious for Caucasians and Blacks women. Caucasians women said almost always no when they meet someone of a different race (20%), when Blacks women say almost always yes when they meet Blacks men (90%).

# %%
#color_palette2 = {"Asian":"y", "Black/African":"brown", "Latino/Hispanic":"r", "Other":"g", "White-Caucasian/European":"b"}

fig, ax= plt.subplots(2,2, figsize=(18, 12))

data[(data['samerace']=='No') & (data.gender=='Woman')][['race', 'dec']].groupby('race').mean().plot(kind='bar', ax=ax[0][0], legend=False,
                                                        title='Different races, Females', ylim=(0,1))#, color=('r', 'g', 'b', 'm', 'y'))
ax[0][0].set_xticklabels(ax[0][0].get_xticklabels(), fontsize=10, rotation=0)

data[(data['samerace']=='No') & (data.gender=='Man')][['race', 'dec']].groupby('race').mean().plot(kind='bar', ax=ax[1][0], legend=False,
                                                        title='Different races, Males', ylim=(0,1))#, color='rgbmy')
ax[1][0].set_xticklabels(ax[1][0].get_xticklabels(), fontsize=10, rotation=0)

data[(data['samerace']=='Yes') & (data.gender=='Woman')][['race', 'dec']].groupby('race').mean().plot(kind='bar', ax=ax[0][1], legend=False,
                                                        title='Same race, Females', ylim=(0,1))#, color= color_palette2)
ax[0][1].set_xticklabels(ax[0][1].get_xticklabels(), fontsize=10, rotation=0)

data[(data['samerace']=='Yes') & (data.gender=='Man')][['race', 'dec']].groupby('race').mean().plot(kind='bar', ax=ax[1][1], legend=False,
                                                        title='Same race, Males', ylim=(0,1))#, color=['r','g','b','m','y'])
ax[1][1].set_xticklabels(ax[1][1].get_xticklabels(), fontsize=10, rotation=0)


fig.suptitle('Rate of positive feedback, by race', fontsize=18)


for i in ax[0][0].patches:
    ax[0][0].text(i.get_x()+.01, i.get_height()+.02, str(round((i.get_height())*100, 1))+'%', fontsize=12)
    
for i in ax[1][0].patches:
    ax[1][0].text(i.get_x()+.01, i.get_height()+.02, str(round((i.get_height())*100, 1))+'%', fontsize=12)
    
for i in ax[0][1].patches:
    ax[0][1].text(i.get_x()+.01, i.get_height()+.02, str(round((i.get_height())*100, 1))+'%', fontsize=12)
    
for i in ax[1][1].patches:
    ax[1][1].text(i.get_x()+.01, i.get_height()+.02, str(round((i.get_height())*100, 1))+'%', fontsize=12)

# %% [markdown]
# ### Religion importance

# %%
data_unique_id['imprelig'].value_counts().sort_index()
# Out:
# 1.0     206
# 2.0      53
# 3.0      62
# 4.0      35
# 5.0      48
# 6.0      38
# 7.0      31
# 8.0      33
# 9.0      18
# 10.0     20
# Name: imprelig, dtype: int64

# %%
print(f"Mean of religion importance : {data_unique_id['imprelig'].mean()}")
print(f"Mean of religion importance for women: {data_unique_id['imprelig'].loc[data_unique_id['gender'] == 'Woman'].mean()}")
print(f"Mean of religion importance for men: {data_unique_id['imprelig'].loc[data_unique_id['gender'] == 'Man'].mean()}")
# Out:
# Mean of religion importance : 3.582720588235294
# Mean of religion importance for women: 4.144981412639405
# Mean of religion importance for men: 3.0327272727272727

# %% [markdown]
# Religion seems to be more important for women than for men, one more time.

# %%
fig = sns.countplot(x = "imprelig", data = data_unique_id, hue = 'gender', palette=color_palette).set(title="Importance of the Religion per gender")

# %%
data_unique_id[['race', 'imprelig']].groupby(['race']).agg(['mean', 'min', 'max', 'count'])
# Out:
#                           imprelig
#                               mean  min   max count
# race
# Asian                     3.036765  1.0  10.0   136
# Black/African             3.076923  1.0  10.0    26
# Latino/Hispanic           3.261905  1.0  10.0    42
# Other                     3.432432  1.0  10.0    37
# White-Caucasian/European  3.933993  1.0  10.0   303

# %% [markdown]
# Religion is more important for Caucasian than for other races, but there is not a big difference.

# %%
# Importance of religion for each race
fig = sns.FacetGrid(data_unique_id, col='race')
fig.map(plt.hist, 'imprelig', bins=10)
axes = fig.axes.flatten()
axes[0].set_title("Asian")
axes[1].set_title("White")
axes[2].set_title("Other")
axes[3].set_title("Hispanic")
axes[4].set_title("Black")
plt.subplots_adjust(top=0.75)
fig.fig.suptitle('Importance of race for each race', fontsize=15)
# Out:
# Text(0.5, 0.98, 'Importance of race for each race')

# %%
data_unique_id[['gender', 'race', 'imprelig']].groupby(['gender', 'race']).agg(['mean', 'min', 'max', 'count'])
# Out:
#                                  imprelig
#                                      mean  min   max count
# gender race
# Man    Asian                     2.476923  1.0   8.0    65
#        Black/African             1.800000  1.0   4.0    10
#        Latino/Hispanic           3.117647  1.0   9.0    17
#        Other                     2.476190  1.0   9.0    21
#        White-Caucasian/European  3.395062  1.0  10.0   162
# Woman  Asian                     3.549296  1.0  10.0    71
#        Black/African             3.875000  1.0  10.0    16
#        Latino/Hispanic           3.360000  1.0  10.0    25
#        Other                     4.687500  1.0  10.0    16
#        White-Caucasian/European  4.553191  1.0  10.0   141

# %%
color_palette2 = ['yellow', 'brown', 'orange', 'green', 'blue']

fig, ax= plt.subplots(1,2, figsize=(15, 7.5))

data_unique_id[data_unique_id.gender=='Woman'][['race', 'imprelig']].groupby('race').mean().T.plot(kind='bar', ax=ax[0], legend=True,
                                                    title='Females', ylim=(1,5), color=color_palette2)
ax[0].set_xticklabels(ax[0].get_xticklabels(), fontsize=8, rotation='horizontal')

data_unique_id[data_unique_id.gender=='Man'][['race', 'imprelig']].groupby('race').mean().T.plot(kind='bar', ax=ax[1], legend=True,
                                                    title='Males', ylim=(1,5), color=color_palette2)
ax[1].set_xticklabels(ax[1].get_xticklabels(), fontsize=8, rotation='horizontal')

fig.suptitle('Mean importance of religion, by race', fontsize=22)

for i in ax[0].patches:
    ax[0].text(i.get_x()+.03, i.get_height()+.03, str(round((i.get_height()), 1)), fontsize=12)
    
for i in ax[1].patches:
    ax[1].text(i.get_x()+.03, i.get_height()+.03, str(round((i.get_height()), 1)), fontsize=12)

# %% [markdown]
# Caucasian and Others women give more importance to religion than other races. We can see a big gap between gender for Blacks and Others races. For Asians and Caucasians also we can see the difference between men and women, but it is less important than for Blacks and Others participants.

# %%
fig, ax= plt.subplots(1,2, figsize=(15, 6))

data_unique_id[data_unique_id.gender=='Woman'][['race', 'imprelig']].groupby('race').mean().plot(kind='bar', ax=ax[0], legend=False,
                                                    title='Females', ylim=(1,5))#, color='rgbmy')
ax[0].set_xticklabels(ax[0].get_xticklabels(), fontsize=8, rotation='horizontal')

data_unique_id[data_unique_id.gender=='Man'][['race', 'imprelig']].groupby('race').mean().plot(kind='bar', ax=ax[1], legend=False,
                                                    title='Males', ylim=(1,5))#, color='rgbmy')
ax[1].set_xticklabels(ax[1].get_xticklabels(), fontsize=8, rotation='horizontal')

fig.suptitle('Mean importance of religion, by race', fontsize=22)

for i in ax[0].patches:
    ax[0].text(i.get_x()+.1, i.get_height()+.05, str(round((i.get_height()), 1)), fontsize=12)
    
for i in ax[1].patches:
    ax[1].text(i.get_x()+.1, i.get_height()+.05, str(round((i.get_height()), 1)), fontsize=12)

# %%
print(f"Percentage of match for people for who religion is quite important : {data['match'].loc[(data['imprelig']>5)].sum() / data['match'].loc[(data['imprelig']>5)].count() * 100}")
print(f"Percentage of match for people for who religion is not important : {data['match'].loc[(data['imprelig']<=5)].sum() / data['match'].loc[(data['imprelig']<=5)].count() * 100}")
# Out:
# Percentage of match for people for who religion is quite important : 15.527950310559005
# Percentage of match for people for who religion is not important : 16.790736145574854

# %% [markdown]
# ### Studies & activites

# %% [markdown]
# ### Field of study

# %%
# distribution of the participants's studies
data_unique_id["field_cd"].value_counts()
# Out:
# Business/Finance                           130
# Biological Sciences/Chemistry/Physics       61
# Engineering                                 56
# Law                                         48
# Political Science/International Affairs     46
# Social Science/Psychologist                 46
# Education/Academia                          40
# Social Work                                 30
# English/Creative/Journalism                 21
# History/Religion/Philosophy                 17
# Math                                        14
# Fine Arts/Arts Administration               11
# Medical Science                              9
# Film                                         7
# Languages                                    3
# Other                                        3
# Undergrad/Undecide                           1
# Architecture                                 1
# Name: field_cd, dtype: int64

# %%
# Participants's studies per gender
fig = plt.figure(figsize = (10,10))
fig = sns.countplot(y = "field_cd", data = data_unique_id, hue = "gender", palette=color_palette).set(title="Studies's participants per gender")
fig = plt.yticks (rotation = 0, fontsize = 10)

# %% [markdown]
# A big part of the participant study Business/Finance, with a big proportion of men. Men are also majority in engineering, whearas women mostly study Political Science, Education, Social science, Social work.

# %%
data_unique_id["career_c"].value_counts()
# Out:
# Academic/Research                                                       152
# Banking/Consulting/Finance/Marketing/Business/CEO/Entrepreneur/Admin    144
# Lawyer                                                                   47
# Creative Arts/Entertainment                                              46
# International/Humanitarian Affairs                                       35
# Doctor/Medicine                                                          26
# Undecided                                                                25
# Psychologist                                                             17
# Engineer                                                                 14
# Social Work                                                              14
# Other                                                                     5
# Politics                                                                  5
# ...

# %%
# Participants's career per gender
fig = plt.figure(figsize = (10,10))
fig = sns.countplot(y = "career_c", data = data_unique_id, hue = "gender", palette=color_palette).set(title="Participants's intended career per gender")

fig = plt.yticks (rotation = 0, fontsize = 10)

# %% [markdown]
# Most of participant career's field are Academic/Research, and Banking/Consulting/Finance/Marketing/Business/CEO/Entrepreneur/Admin. We can see than there is much more men than women who intend to work in Banking/Consulting/Finance/... or Lawyer, whereas it is inversed for International/Humanitarian Affairs and Academic/Research. We can see almost only girls who intend to work in Social Work and Psychologist.

# %% [markdown]
# ### Goal, Date and Going out

# %%
data_unique_id["goal"].value_counts()
# Out:
# Seemed like a fun night out           228
# To meet new people                    189
# To get a date                          40
# To say I did it                        35
# Other                                  30
# Looking for a serious relationship     22
# Name: goal, dtype: int64

# %% [markdown]
# Most of the people declare to be there to have fun and meet new people.

# %%
# Distributions of goals per gender 
fig = plt.figure(figsize = (7,5))
fig = sns.countplot(y = "goal", data = data_unique_id, hue = "gender", palette=color_palette).set(title="Participants's intended goals per gender")
fig = plt.yticks (rotation = 0, fontsize = 11)

# %% [markdown]
# The intentions seems to be the same for both gender. We can only see a main difference for men who want twice more To get a date than women. The main part of the population wants to meet poeple or have fun.

# %%
data_unique_id["date"].value_counts()
# Out:
# Several times a year    136
# Twice a month           131
# Once a month             99
# Almost never             94
# Once a week              54
# Twice a week             22
# Several times a week      7
# Name: date, dtype: int64

# %%
# The frenquencies of going on dates per gender
fig = plt.figure(figsize = (7,7))
fig = sns.countplot(y = "date", data = data_unique_id, hue = "gender", palette=color_palette).set(title="The frequencies of going on dates per gender")
fig = plt.yticks (rotation = 0, fontsize = 11)

# %% [markdown]
# There is more women that almost never going on date than men. There is more men going on date at least once a week than women. Between those two extremity, it is almost distributed equitably for both gender.

# %%
data_unique_id["go_out"].value_counts()
# Out:
# Twice a week            191
# Several times a week    177
# Once a week             127
# Twice a month            29
# Once a month             12
# Several times a year      6
# Almost never              2
# Name: go_out, dtype: int64

# %%
# The frenquencies of going out per gender
fig = plt.figure(figsize = (7,7))
fig = sns.countplot(y = "go_out", data = data_unique_id, hue = "gender", palette=color_palette).set(title="The frequencies of going out per gender")
fig = plt.xticks(rotation=90)
fig = plt.yticks (rotation = 0, fontsize = 11)

# %% [markdown]
# You can see that almost as many women as men go out. More men go out twice a week, when more women go out once a week. But the big majority of the population declare to go out at least once a week.

# %%
pd.crosstab(data['go_out'], data['date'], normalize='index')
# Out:
# date                  Almost never  Once a month  Once a week  \
# go_out
# Almost never              1.000000      0.000000     0.000000
# Once a month              0.128049      0.384146     0.000000
# Once a week               0.212417      0.212417     0.042073
# Several times a week      0.123755      0.131418     0.159004
# Several times a year      0.090909      0.222222     0.000000
# Twice a month             0.437778      0.146667     0.000000
# Twice a week              0.145693      0.208614     0.096231
#
# date                  Several times a week  Several times a year  \
# go_out
# Almost never                      0.000000              0.000000
# Once a month                      0.000000              0.487805
# Once a week                       0.000000              0.302719
# Several times a week              0.036015              0.159387
# Several times a year              0.000000              0.686869
# ...

# %% [markdown]
# Without surprises, the more the participants go out, the more they have dates. They seem to go out more than they have dates, except for : 1,7% of poeple who go out once a week and have dates twice a week, and 22,2% of poeple who go out several times a year and have dates once a month.

# %%
shared_interests = data[["gender","sports", "tvsports", "exercise", "dining", "museums", "art", "hiking", "gaming", "clubbing", "reading", "tv", "theater", "movies", "concerts", "music", "shopping", "yoga"]].groupby("gender").mean()
cols_interests = ["Sports", "TV Sports", "Exercise/Gym", "Dining", "Museums", "Art", "Hiking", "Gaming", "Clubbing", "Reading", "Watching TV", "Theater", "Movies/Cinema", "Concers", "Music", "Shopping", "Yoga"]
shared_interests.columns = cols_interests

men_interests = go.Bar(
    y=list(shared_interests.iloc[1]),
    x=shared_interests.columns.values,
    name="Women",
    marker=dict(
        color="red"
    )
)
women_interests = go.Bar(
    y=list(shared_interests.iloc[0]),
    x=shared_interests.columns.values,
    name="Men",
    marker=dict(
        color="blue"
    )
)

data_interests = [men_interests, women_interests]
layout = go.Layout(
    title="Interests per gender",
    font=dict(
        size=15
    ),
    legend=dict(
        font=dict(
            size=15
        )
    )
)
fig = go.Figure(data=data_interests, layout=layout)
fig.show()
#py.iplot(fig, filename='barchart')

# %% [markdown]
# Men prefer Sports, watch Sports on TV and Gaming more than women. Women prefer all the other activities more than men, especially for Shopping, Yoga, and Theater.

# %% [markdown]
# ### Attributes

# %% [markdown]
# What you look for in the opposite sex ?

# %%
fig_look_o_sex = go.Figure()

data_men = data_unique_id.loc[data_unique_id["gender"] == "Man",:]
data_women = data_unique_id.loc[data_unique_id["gender"] == "Woman",:]
cols = ["Attractive","Sincere","Intelligente","Fun","Ambituous","Shared Interests"]

fig_look_o_sex.add_trace(go.Scatterpolar(
    r=[data_men["attr1_1"].mean(), data_men["sinc1_1"].mean() , data_men["intel1_1"].mean(),data_men["fun1_1"].mean(),data["amb1_1"].mean(),data_men["shar1_1"].mean() ],
    theta=cols,
    fill="toself",
    name="Men",
    marker=dict(
      color="blue"
    )
))
fig_look_o_sex.add_trace(go.Scatterpolar(
    r=[data_women["attr1_1"].mean(), data_women["sinc1_1"].mean() , data_women["intel1_1"].mean(),data_women["fun1_1"].mean(),data_women["amb1_1"].mean(),data_women["shar1_1"].mean() ],
    theta=cols,
    fill="toself",
    name="Women",
    marker=dict(
      color="red"
    )
))

fig_look_o_sex.show()

# %% [markdown]
# We can see that men are looking for attractive women much more than women are looking for attractive men. They both are looking for the same level of fun in the opposite sex.
#
# Women are more looking for intelligent, sincere and ambitious men. We can't say that girls just want to have fun, because it comes in fourth position of wanted attributes after intelligence, sincerity and attractiveness.
#
# Men are clearly looking for attractive women first, then come intelligence, fun and sincerity.
#
# Ambition and shared interests are less important for both sex, even if girls give it more importance than boys.

# %% [markdown]
# What do you think the opposite sex looks for in a date ?

# %%
fig_date_o_look = go.Figure()

fig_date_o_look.add_trace(go.Scatterpolar(
    r=[data_men["attr2_1"].mean(), data_men["sinc2_1"].mean() , data_men["intel2_1"].mean(),data_men["fun2_1"].mean(),data["amb2_1"].mean(),data_men["shar2_1"].mean() ],
    theta=cols,
    fill="toself",
    name="Men",
    marker=dict(
        color="blue"
    )
))
fig_date_o_look.add_trace(go.Scatterpolar(
    r=[data_women["attr2_1"].mean(), data_women["sinc2_1"].mean() , data_women["intel2_1"].mean(),data_women["fun2_1"].mean(),data_women["amb2_1"].mean(),data_women["shar2_1"].mean() ],
    theta=cols,
    fill="toself",
    name="Women",
    marker=dict(
        color="red"
    )
))

fig_date_o_look.show()

# %% [markdown]
# They both think that opposite sex is looking for attractive partner more than all other attributes. Men think women are looking for fun and intellingence after attractiveness, when women clearly think men want women to be attractive and a bit fun.
#
# Women overestimate the fact that men are looking for attractiveness (+12.4 between what men are looking for (27.2) and what women think men are looking for (35.6)). However they underestimate the want for men to have a partner intelligent and sincere (respectivelly 19.4 and 16.4 for what men are looking for, compared to 12.5 and 11.3 for what women thinl men are looking for).
#
# It is the same for men but in lower proportion. They overestimate the want for women of being attractive (18 for what women are looking for against 25 for what men think women want), and they underestimate intelligence (16.3 against 21) and sincerity (15.1 against 18.2);

# %% [markdown]
# How do you think you measure up ?

# %%
fig_own = go.Figure()

fig_own.add_trace(go.Scatterpolar(
    r=[data_men["attr3_1"].mean(), data_men["sinc3_1"].mean() , data_men["intel3_1"].mean(),data_men["fun3_1"].mean(),data_men["amb3_1"].mean()],
    theta=cols[:-1],
    name="Men",
    fill="toself",
    marker=dict(
        color="blue"
    )
))
fig_own.add_trace(go.Scatterpolar(
    r=[data_women["attr3_1"].mean(), data_women["sinc3_1"].mean() , data_women["intel3_1"].mean(),data_women["fun3_1"].mean(),data_women["amb3_1"].mean()],
    theta=cols[:-1],
    name="Women",
    fill="toself",
    marker=dict(
        color="hotpink"
    )
))

fig_own.show()

# %% [markdown]
# We can see that there is not so much differences between women and men in the way they perceive themself. They are really close in the way to rate themself, even if women estimate themself a little bit more sincere, attractive and fun than men, whereas men estimate themself a little bit more intelligent.

# %% [markdown]
# What you think MOST of your fellow men/women look for in the opposite sex ?

# %%
fig_think_o_look = go.Figure()

fig_think_o_look.add_trace(go.Scatterpolar(
    r=[data_men["attr4_1"].mean(), data_men["sinc4_1"].mean() , data_men["intel4_1"].mean(),data_men["fun4_1"].mean(),data["amb4_1"].mean(),data_men["shar4_1"].mean() ],
    theta=cols,
    fill="toself",
    name="Men",
    marker=dict(
        color="blue"
    )
))
fig_think_o_look.add_trace(go.Scatterpolar(
    r=[data_women["attr4_1"].mean(), data_women["sinc4_1"].mean() , data_women["intel4_1"].mean(),data_women["fun4_1"].mean(),data_women["amb4_1"].mean(),data_women["shar4_1"].mean() ],
    theta=cols,
    fill="toself",
    name="Women",
    marker=dict(
        color="red"
    )
))

fig_think_o_look.show()

# %% [markdown]
# The attribute that each sex think their fellow are looking for is clearly attractiveness. It is even more pronounced for men who think that their fellow are looking for attractive wome, much more than girl (28.3 against 24.3).
#
# For men it is in adequation with the level each man said he was looking for in the opposite sex (28.3 for what they think they fellow look for, against 27.2 for what they say they look for), but for girls it is quite surpirising to see that they think their fellow look for atrractiveness much more than each woman said she was looking for in the opposite sex (24.3 for what they think they fellow look for, against 18 for what they say they look for).
#
# The second attribute men and women think their fellow are looking for is fun.
# Men think their fellow are less looking for intelligence (12), sincerity (10.8) and fun (16.1) than what they are really looking for (respectivelly 19.4, 16.4 and 17.6). It is almost the same for girls, but even more pronouced. They think their fellow are less looking for intelligence (13), sincerity (11.4) and fun (15.1) than what they are really looking for (respectivelly 21, 18.2 and 17.3).

# %% [markdown]
# How do you think others perceive you ?

# %%
fig_perceive = go.Figure()

fig_perceive.add_trace(go.Scatterpolar(
    r=[data_men["attr5_1"].mean(), data_men["sinc5_1"].mean() , data_men["intel5_1"].mean(),data_men["fun5_1"].mean(),data["amb5_1"].mean()],
    theta=cols[:-1],
    fill="toself",
    name="Men",
    marker=dict(
        color="blue"
    )
))
fig_perceive.add_trace(go.Scatterpolar(
    r=[data_women["attr5_1"].mean(), data_women["sinc5_1"].mean() , data_women["intel5_1"].mean(),data_women["fun5_1"].mean(),data_women["amb5_1"].mean()],
    theta=cols[:-1],
    fill="toself",
    name="Women",
    marker=dict(
        color="red"
    )
))

fig_perceive.show()

# %% [markdown]
# Like how they measure themself, there is not so much differences between women and men in the way they think other perceive them. Men think other perceive them intelligent, more than women. Women think other perceive them as attractive, sincere, fun and ambitious.

# %% [markdown]
# ### Conclusion

# %% [markdown]
# Throw this analysis and those visualisations, the marketing team of Tinder will understand better what makes people interested into each other.
# This study demonstrate some key matching preferences observed in the dataset, providing valuable information about the interests that contribute to successful matches. \
# We notice notably :\
# * The majority of couples are composed of women 2 years older to 3 years younger than men.
# * Race and Religion are more important for women than for men.
# * Physical attractiveness remains one of the most important criteria, mainly for men, it's more balanced for women.
